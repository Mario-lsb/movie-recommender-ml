# %%
import sys
sys.path.append("..")

import joblib

from src.collaborative.matrix_factorization import train_svd

# load ratings again
import pandas as pd
ratings = pd.read_csv("../data/raw/ratings.csv")

svd, latent_matrix = train_svd(ratings)

joblib.dump(
    svd,
    "../model/svd_model.pkl"
)

print("Model saved successfully")
# Out:
# Model saved successfully
